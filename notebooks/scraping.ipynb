# %% [markdown]
# **Werkwijze:**
#
# 1️⃣ Eerst heb ik geïdentificeerd welke pagina’s afbeeldingen bevatten en deze opgeslagen in een lijst.
#
# 2️⃣ Op iedere pagina heb ik via `requests` de HTML-bron opgehaald en met `BeautifulSoup` alle `<img>`-tags uitgelezen.
#
# 3️⃣ Omdat de site **thumbnail-plaatjes** gebruikt, waarbij de originele afbeelding pas zichtbaar wordt wanneer je `thmbnl` uit de bestandsnaam haalt, heb ik een omzet-functie gemaakt die automatisch de juiste full-resolution URL afleidt.
#
# 4️⃣ Sommige thumbnails hadden géén full-image op de server → in die gevallen heb ik een **fallback** toegevoegd die de thumbnail zelf opslaat.
#
# 5️⃣ De site bevat ook veel **niet-relevante afbeeldingen** zoals spacers, advertenties, logo’s en achtergronden. Deze heb ik gefilterd op basis van sleutelwoorden (bv. `spacer`, `logo`, `banner`).
#
# 6️⃣ Alle afbeeldingen zijn vervolgens in **één map** opgeslagen, waarbij bestandsnamen automatisch werden opgeschoond (bijv. `"thmbnl_portrait.jpg"` → `"portrait.jpg"`).
#
# 7️⃣ Tot slot print het script een **samenvatting** met het aantal gevonden thumbnails, opgeslagen full-images en fallback-thumbnails.

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import os
import os.path as op


# te scrapen pagina's
PAGES = [
    "https://www.rembrandtpainting.net/rembrandt_painting_1626-35.htm",
    "https://www.rembrandtpainting.net/rembrandt_painting_1636_54.htm",
    "https://www.rembrandtpainting.net/rembrandt_painting_1655-69.htm",
    "https://www.rembrandtpainting.net/rembrandt_self_portraits.htm",
    "https://www.rembrandtpainting.net/rembrandt_drawings_start.htm",
    "https://www.rembrandtpainting.net/rmbrdnt_selected_etchings/rembrandt_etchings.htm",
    "https://www.rembrandtpainting.net/rembrandt's_prodigal_son.html",
    "https://www.rembrandtpainting.net/famous_works.html",
    "https://www.rembrandtpainting.net/rembrandt_books.htm",
]

# output-directory
SAVE_DIR = "rembrandt_images"
os.makedirs(SAVE_DIR, exist_ok=True)

HEADERS = {
    "User-Agent": "Mozilla/5.0 (compatible; RembrandtScraper/1.0)"
}

# Bestandsnaam-patronen om te skippen (UI / layout / ads)
BAD_KEYWORDS = [
    "spacer", "background", "backgrnd", "poster", "dvd", "sign",
    "ad_", "signature", "artcom", "sfumatura", "logo", "banner"
]

VALID_EXTS = (".jpg", ".jpeg", ".png", ".gif")



# HULPFUNCTIES

def build_full_candidates(thumb_url: str) -> list:
    """
    Genereer mogelijke full-size URL's op basis van één thumbnail-URL.
    """
    candidates = []

    # '/thmbnls/' -> '/' + 'thmbnl' overal uit bestandsnaam
    v1 = thumb_url.replace("/thmbnls/", "/")
    v1 = v1.replace("thmbnl_", "").replace("_thmbnl", "").replace("thmbnl", "")
    candidates.append(v1)

    # Alleen 'thmbnl' uit bestandsnaam, map ongewijzigd
    v2 = thumb_url.replace("thmbnl_", "").replace("_thmbnl", "").replace("thmbnl", "")
    if v2 != v1:
        candidates.append(v2)

    return candidates


def clean_filename_from_url(url: str) -> str:
    """
    Haal alleen de bestandsnaam uit de URL en verwijder 'thmbnl' varianten.
    Zorg dat er een geldige extensie op zit.
    """
    name = op.basename(url)

    # 'thmbnl' uit de naam slopen
    name = name.replace("thmbnl_", "").replace("_thmbnl", "").replace("thmbnl", "")

    # Als er geen extensie is, of geen geldige, plak .jpg eraan
    if not any(name.lower().endswith(ext) for ext in VALID_EXTS):
        name += ".jpg"

    return name


def scrape_page(page_url: str) -> dict:
    """
    Scrape één pagina. Alles wordt in SAVE_DIR gezet.
    Retourneert statistieken.
    """
    print("\n=======================================")
    print(f"[PAGE] Start scrape: {page_url}")
    print("=======================================\n")

    # HTML ophalen
    resp = requests.get(page_url, headers=HEADERS)
    resp.raise_for_status()
    soup = BeautifulSoup(resp.text, "html.parser")

    img_tags = soup.find_all("img")
    print(f"[INFO] Gevonden <img>-tags op deze pagina: {len(img_tags)}")

    # Counters voor deze pagina
    count_full = 0
    count_thumb_fallback = 0
    count_skipped_layout = 0
    count_thumbnails_seen = 0

    for img in img_tags:
        src = img.get("src")
        if not src:
            continue

        lower_src = src.lower()

        # layout / advertentie / UI images overslaan
        if any(bad in lower_src for bad in BAD_KEYWORDS):
            count_skipped_layout += 1
            print(f"[SKIP] Layout/advert image: {src}")
            continue

        # alleen thumbnails met 'thmbnl' in de naam
        if "thmbnl" not in lower_src:
            continue

        count_thumbnails_seen += 1

        thumb_url = urljoin(page_url, src)
        print("\n[IMG] Thumbnail:", thumb_url)

        full_candidates = build_full_candidates(thumb_url)
        chosen_full = None
        img_bytes = None

        # probeer full-size kandidaten
        for cand in full_candidates:
            try:
                r = requests.get(cand, headers=HEADERS, timeout=15)
                if r.status_code == 200 and len(r.content) > 500:
                    chosen_full = cand
                    img_bytes = r.content
                    print(f"[OK] Full gevonden: {cand}")
                    break
                else:
                    print(f"[INFO] Kandidaat faalt (status={r.status_code}, size={len(r.content)}): {cand}")
            except Exception as e:
                print(f"[ERROR] Fout bij kandidaat {cand}: {e}")

        # opslaan: full of thumbnail
        if chosen_full and img_bytes:
            filename = clean_filename_from_url(chosen_full)
            save_path = op.join(SAVE_DIR, filename)

            with open(save_path, "wb") as f:
                f.write(img_bytes)

            count_full += 1
            print(f"[SAVE] Full-size opgeslagen als: {save_path}")
        else:
            print("[WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.")
            try:
                r_thumb = requests.get(thumb_url, headers=HEADERS, timeout=15)
                filename = clean_filename_from_url(thumb_url)
                save_path = op.join(SAVE_DIR, filename)

                with open(save_path, "wb") as f:
                    f.write(r_thumb.content)

                count_thumb_fallback += 1
                print(f"[SAVE] Thumbnail opgeslagen als: {save_path}")
            except Exception as e:
                print(f"[ERROR] Kon thumbnail ook niet opslaan: {e}")

    total_saved = count_full + count_thumb_fallback

    # Samenvatting voor deze pagina
    print("\n----------- PAGINA SAMENVATTING -----------")
    print(f"Pagina                       : {page_url}")
    print(f"Gezién thumbnails (thmbnl)   : {count_thumbnails_seen}")
    print(f"Overgeslagen layout/ads      : {count_skipped_layout}")
    print(f"Full-size opgeslagen         : {count_full}")
    print(f"Thumbnail-fallbacks          : {count_thumb_fallback}")
    print(f"TOTAAL opgeslagen (deze pag) : {total_saved}")
    print("-------------------------------------------\n")

    return {
        "page": page_url,
        "thumbs_seen": count_thumbnails_seen,
        "skipped_layout": count_skipped_layout,
        "full": count_full,
        "thumb_fallback": count_thumb_fallback,
        "total_saved": total_saved,
    }


# scraping van de pagina's
all_stats = []

for url in PAGES:
    stats = scrape_page(url)
    all_stats.append(stats)

# Globale samenvatting
global_full = sum(s["full"] for s in all_stats)
global_thumb_fallback = sum(s["thumb_fallback"] for s in all_stats)
global_total = sum(s["total_saved"] for s in all_stats)
global_thumbs_seen = sum(s["thumbs_seen"] for s in all_stats)
global_skipped = sum(s["skipped_layout"] for s in all_stats)

print("\n=======================================")
print("           GLOBALE SAMENVATTING        ")
print("=======================================")
print(f"Totaal pagina's gescrapet        : {len(PAGES)}")
print(f"Totaal gezién thumbnails         : {global_thumbs_seen}")
print(f"Totaal overgeslagen layout/ads   : {global_skipped}")
print(f"Totaal full-size opgeslagen      : {global_full}")
print(f"Totaal thumbnail-fallbacks       : {global_thumb_fallback}")
print("---------------------------------------")
print(f"TOTAAL afbeeldingen opgeslagen   : {global_total}")
print(f"Uitvoer-map                      : {SAVE_DIR}")
print("=======================================\n")
# Out:
# =======================================
# [PAGE] Start scrape: https://www.rembrandtpainting.net/rembrandt_painting_1626-35.htm
# =======================================
#
# [INFO] Gevonden <img>-tags op deze pagina: 53
# [SKIP] Layout/advert image: graphics/ad_signature.jpg
# [SKIP] Layout/advert image: graphics/artcomposter_c.jpg
# [SKIP] Layout/advert image: graphics/ad_signature.jpg
# [SKIP] Layout/advert image: graphics/dvdrembrandtsmall.jpg
# [SKIP] Layout/advert image: graphics/spacerx.gif
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/thmbnl_musical_allegory.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/musical_allegory.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\musical_allegory.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/thmbnl_history_painting.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/history_painting.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\history_painting.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/thmbnl_blind_hermit.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/blind_hermit.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\blind_hermit.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/thmbnl_earlywork.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/earlywork.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\earlywork.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/thmbnls/smlrstudio.jpg
# [INFO] Kandidaat faalt (status=404, size=5077): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/smlrstudio.jpg
# [INFO] Kandidaat faalt (status=404, size=5081): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/s/smlrstudio.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\smlrstudio.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/thmbnls/smlr28.jpg
# [INFO] Kandidaat faalt (status=404, size=5069): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/smlr28.jpg
# [INFO] Kandidaat faalt (status=404, size=5073): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/s/smlr28.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\smlr28.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/thmbnl_dahlia.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/dahlia.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\dahlia.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/thmbnls/smlr29.jpg
# [INFO] Kandidaat faalt (status=404, size=5069): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/smlr29.jpg
# [INFO] Kandidaat faalt (status=404, size=5073): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/s/smlr29.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\smlr29.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/thmbnl_andromeda.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/andromeda.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\andromeda.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/thmbnl_saul.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/saul.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\saul.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/thmbnl_saint_paul.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/saint_paul.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\saint_paul.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/thmbnl_judas_repentent.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/judas_repentent.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\judas_repentent.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/thmbnls/smlromdwoman.jpg
# [INFO] Kandidaat faalt (status=404, size=5081): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/smlromdwoman.jpg
# [INFO] Kandidaat faalt (status=404, size=5085): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/s/smlromdwoman.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\smlromdwoman.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/thmbnl_officer.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/officer.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\officer.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/thmbnl_rembrandt's_mother.jpg
# [INFO] Kandidaat faalt (status=404, size=5073): https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/rembrandt's_mother.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\rembrandt's_mother.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/thmbnls/smlrjeremiah.jpg
# [INFO] Kandidaat faalt (status=404, size=5081): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/smlrjeremiah.jpg
# [INFO] Kandidaat faalt (status=404, size=5085): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/s/smlrjeremiah.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\smlrjeremiah.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/thmbnls/smlroldman.jpg
# [INFO] Kandidaat faalt (status=404, size=5077): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/smlroldman.jpg
# [INFO] Kandidaat faalt (status=404, size=5081): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/s/smlroldman.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\sm
https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/smlrmbrndelephant.jpg
# [INFO] Kandidaat faalt (status=404, size=5095): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/s/smlrmbrndelephant.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\smlrmbrndelephant.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_saskia_and_hat.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/saskia_and_hat.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\saskia_and_hat.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/thmbnls/elephant_vienna_thmb.jpg
# [INFO] Kandidaat faalt (status=404, size=5097): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/elephant_vienna_thmb.jpg
# [INFO] Kandidaat faalt (status=404, size=5101): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/s/elephant_vienna_thmb.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\elephant_vienna_thmb.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_angel.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/angel.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\angel.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_old_costume.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/old_costume.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\old_costume.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_christ_and_magdalen.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/christ_and_magdalen.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\christ_and_magdalen.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_maria_trip.jpg
# [INFO] Kandidaat faalt (status=404, size=5061): https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/maria_trip.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\maria_trip.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_birds.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/birds.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\birds.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/thmbnls/smlrland.jpg
# [INFO] Kandidaat faalt (status=404, size=5073): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/smlrland.jpg
# [INFO] Kandidaat faalt (status=404, size=5077): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/s/smlrland.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\smlrland.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_unnfinished.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/unnfinished.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\unnfinished.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnlnew_portrait_of_a_woman.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/new_portrait_of_a_woman.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\new_portrait_of_a_woman.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/thmbnls/smlrmbrndchild.jpg
# [INFO] Kandidaat faalt (status=404, size=5085): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/smlrmbrndchild.jpg
# [INFO] Kandidaat faalt (status=404, size=5089): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/s/smlrmbrndchild.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\smlrmbrndchild.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/thmbnls/smlrbridge.jpg
# [INFO] Kandidaat faalt (status=404, size=5077): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/smlrbridge.jpg
# [INFO] Kandidaat faalt (status=404, size=5081): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/s/smlrbridge.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\smlrbridge.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_mennonite_preacher.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/mennonite_preacher.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\mennonite_preacher.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_bambeck_portrait.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/bambeck_portrait.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\bambeck_portrait.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_david_and_jonathan.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/david_and_jonathan.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\david_and_jonathan.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_night_watch.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/night_watch.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\night_watch.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/thmbnls/smlbas.jpg
# [INFO] Kandidaat faalt (status=404, size=5069): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/smlbas.jpg
# [INFO] Kandidaat faalt (status=404, size=5073): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/s/smlbas.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\smlbas.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_adultery.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/adultery.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\adultery.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_saskiabis.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/saskiabis.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\saskiabis.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_the_holy_family.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/the_holy_family.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\the_holy_family.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_girl_at_window.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/girl_at_window.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\girl_at_window.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_nativity.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/nativity.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\nativity.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_flight_from_egypt.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/flight_from_egypt.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\flight_from_egypt.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/thmbnls/smlrbueno.jpg
# [INFO] Kandidaat faalt (status=404, size=5075): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/smlrbueno.jpg
# [INFO] Kandidaat faalt (status=404, size=5079): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/s/smlrbueno.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\smlrbueno.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/complete_catalogue/storia_b/images/thmbnl_emmaus.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/complete_catalogue/storia_b/images/emmaus.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\emmaus.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_gold_helmet.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/gold_helmet.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\gold_helmet.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/complete_catalogue/portraits/images/girlwithabroom_thmbnl.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/complete_catalogue/portraits/images/girlwithabroom.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\girlwithabroom.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/thmbnls/thmbnl_lion.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/lion.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\lion.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_homer.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/homer.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\homer.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/thmbnls/smlrsaskia.jpg
# [INFO] Kandidaat faalt (status=404, size=5077): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/smlrsaskia.jpg
# [INFO] Kandidaat faalt (status=404, size=5081): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/s/smlrsaskia.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\smlrsaskia.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_oldman_in_costume.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/oldman_in_costume.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\oldman_in_costume.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_jan_six.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/jan_six.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\jan_six.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_flora.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/flora.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\flora.jpg
#
# ----------- PAGINA SAMENVATTING -----------
# Pagina                       : https://www.rembrandtpainting.net/rembrandt_painting_1636_54.htm
# Gezién thumbnails (thmbnl)   : 37
# Overgeslagen layout/ads      : 5
# Full-size opgeslagen         : 26
# Thumbnail-fallbacks          : 11
# TOTAAL opgeslagen (deze pag) : 37
# -------------------------------------------
#
#
# =======================================
# [PAGE] Start scrape: https://www.rembrandtpainting.net/rembrandt_painting_1655-69.htm
# =======================================
#
# [INFO] Gevonden <img>-tags op deze pagina: 40
# [SKIP] Layout/advert image: graphics/ad_signature.jpg
# [SKIP] Layout/advert image: graphics
jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\holy_family.jpg
#
# ----------- PAGINA SAMENVATTING -----------
# Pagina                       : https://www.rembrandtpainting.net/rembrandt_painting_1655-69.htm
# Gezién thumbnails (thmbnl)   : 29
# Overgeslagen layout/ads      : 10
# Full-size opgeslagen         : 23
# Thumbnail-fallbacks          : 6
# TOTAAL opgeslagen (deze pag) : 29
# -------------------------------------------
#
#
# =======================================
# [PAGE] Start scrape: https://www.rembrandtpainting.net/rembrandt_self_portraits.htm
# =======================================
#
# [INFO] Gevonden <img>-tags op deze pagina: 44
# [SKIP] Layout/advert image: graphics/ad_signature.jpg
# [SKIP] Layout/advert image: graphics/artcomposter_c.jpg
# [SKIP] Layout/advert image: graphics/ad_signature.jpg
# [SKIP] Layout/advert image: graphics/dvdrembrandtsmall.jpg
# [SKIP] Layout/advert image: graphics/spacerx.gif
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/thmbnl_slfptrt_c.1627-1628.jpg
# [INFO] Kandidaat faalt (status=404, size=5067): https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/slfptrt_c.1627-1628.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\slfptrt_c.1627-1628.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/thmbnl_slfptrt_leaning_forward_c.1628.jpg
# [INFO] Kandidaat faalt (status=404, size=5089): https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/slfptrt_leaning_forward_c.1628.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\slfptrt_leaning_forward_c.1628.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/thmbnl_slfptrt_as_%20young_man_1628.jpg
# [INFO] Kandidaat faalt (status=404, size=5081): https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/slfptrt_as_%20young_man_1628.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\slfptrt_as_%20young_man_1628.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/thmbnl_self_portrait_drawing.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/self_portrait_drawing.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\self_portrait_drawing.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/thmbnl_slfptrt_as_young%20man%201629.jpg
# [INFO] Kandidaat faalt (status=404, size=5079): https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/slfptrt_as_young%20man%201629.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\slfptrt_as_young%20man%201629.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/thmbnl_self_portrait_young.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/self_portrait_young.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\self_portrait_young.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/thmbnl_gorget_beret.jpg
# [INFO] Kandidaat faalt (status=404, size=5053): https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/gorget_beret.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\gorget_beret.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/thmbnl_sflprtrt_plummed_hat.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/sflprtrt_plummed_hat.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\sflprtrt_plummed_hat.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/thmbnl_slfptrt_wid_%20eyed_1630.jpg
# [INFO] Kandidaat faalt (status=404, size=5073): https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/slfptrt_wid_%20eyed_1630.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\slfptrt_wid_%20eyed_1630.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/thmbnl_slfptrt_as_%20beggar.jpg
# [INFO] Kandidaat faalt (status=404, size=5065): https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/slfptrt_as_%20beggar.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\slfptrt_as_%20beggar.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/thmbnl_portrait_%20rembrandt_in_oriental_attirre.jpg
# [INFO] Kandidaat faalt (status=404, size=5115): https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/portrait_%20rembrandt_in_oriental_attirre.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\portrait_%20rembrandt_in_oriental_attirre.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/thmbnl_slfptrt_with_loose_hair.jpg
# [INFO] Kandidaat faalt (status=404, size=5075): https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/slfptrt_with_loose_hair.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\slfptrt_with_loose_hair.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/thmbnl_slfptrt_with_wide-brimmed_hat.jpg
# [INFO] Kandidaat faalt (status=404, size=5087): https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/slfptrt_with_wide-brimmed_hat.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\slfptrt_with_wide-brimmed_hat.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/thmbnl_self_portrait_smiling.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/self_portrait_smiling.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\self_portrait_smiling.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/thmbnl_self_portrait_helmet.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/self_portrait_helmet.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\self_portrait_helmet.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrdnt_selected_etchings/etching_thmbnls/kris.gif
# [INFO] Kandidaat faalt (status=404, size=5053): https://www.rembrandtpainting.net/rmbrdnt_selected_etchings/etchings/kris.gif
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\kris.gif
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/thmbnl_self_portrait_oval.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/self_portrait_oval.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\self_portrait_oval.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/thmbnl_slfptrt_with_saskia_1636.jpg
# [INFO] Kandidaat faalt (status=404, size=5077): https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/slfptrt_with_saskia_1636.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\slfptrt_with_saskia_1636.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/thmbnl_slfptrt_seated_1636.jpg
# [INFO] Kandidaat faalt (status=404, size=5067): https://www.rembrandtpainting.net/slf_prtrts/slf_prtrts_imgs/slfptrt_seated_1636.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\slfptrt_seated_1636.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrdnt_selected_etchings/selected_etchings_images/thmbnl_leaning_on_stone_wall.jpg
# [INFO] Kandidaat faalt (status=404, size=5119): https://www.rembrandtpainting.net/rmbrdnt_selected_etchings/selected_etchings_images/leaning_on_stone_wall.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\leaning_on_stone_wall.jpg
#
# ...
# [OK] Full gevonden: https://www.rembrandtpainting.net/complete_catalogue/landscape/images/windmill.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\windmill.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/thmbnl_dr_tulp.jpg
# [INFO] Kandidaat faalt (status=404, size=5051): https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/dr_tulp.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\dr_tulp.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/thmbnl_woman_smiling.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/woman_smiling.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\woman_smiling.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/thmbnl_christ_in_the_storm.jpg
# [INFO] Kandidaat faalt (status=404, size=5075): https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/christ_in_the_storm.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\christ_in_the_storm.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/thmbnl_belshazzar.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/belshazzar.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\belshazzar.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/thmbnl_prodigal.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1620-35/1620_35_images/prodigal.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\prodigal.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_samson.jpg
# [INFO] Kandidaat faalt (status=404, size=5053): https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/samson.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\samson.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_danea.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/danea.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\danea.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/thmbnls/elephant_vienna_thmb.jpg
# [INFO] Kandidaat faalt (status=404, size=5097): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/elephant_vienna_thmb.jpg
# [INFO] Kandidaat faalt (status=404, size=5101): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/s/elephant_vienna_thmb.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\elephant_vienna_thmb.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_susanna_and_the_elders.jpg
# [INFO] Kandidaat faalt (status=404, size=5085): https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/susanna_and_the_elders.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\susanna_and_the_elders.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/thmbnls/thmbnl_birds.jpg
# [INFO] Kandidaat faalt (status=404, size=5067): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/birds.jpg
# [INFO] Kandidaat faalt (status=404, size=5071): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/s/birds.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\birds.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/thmbnls/smlrmbrndelephant.jpg
# [INFO] Kandidaat faalt (status=404, size=5091): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/smlrmbrndelephant.jpg
# [INFO] Kandidaat faalt (status=404, size=5095): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/s/smlrmbrndelephant.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\smlrmbrndelephant.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_angel.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/angel.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\angel.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrdnt_selected_etchings/etching_thmbnls/thmbnl_rembrandt's_mill.jpg
# [INFO] Kandidaat faalt (status=404, size=5077): https://www.rembrandtpainting.net/rmbrdnt_selected_etchings/etchings/rembrandt's_mill.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\rembrandt's_mill.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/thmbnls/thmbnl_cottages.jpg
# [INFO] Kandidaat faalt (status=404, size=5073): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/cottages.jpg
# [INFO] Kandidaat faalt (status=404, size=5077): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/s/cottages.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\cottages.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_night_watch.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/night_watch.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\night_watch.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_david_and_jonathan.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/david_and_jonathan.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\david_and_jonathan.jpg
# [SKIP] Layout/advert image: graphics/head_of_christ_thmb.JPG
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/complete_catalogue/storia_b/images/thmbnl_emmaus.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/complete_catalogue/storia_b/images/emmaus.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\emmaus.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrdnt_selected_etchings/etching_thmbnls/thmbnl_slfprtrt_at_a_window_etching.jpg
# [INFO] Kandidaat faalt (status=404, size=5101): https://www.rembrandtpainting.net/rmbrdnt_selected_etchings/etchings/slfprtrt_at_a_window_etching.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\slfprtrt_at_a_window_etching.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrdnt_selected_etchings/etching_thmbnls/thmbnl_shell.jpg
# [INFO] Kandidaat faalt (status=404, size=5055): https://www.rembrandtpainting.net/rmbrdnt_selected_etchings/etchings/shell.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\shell.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_gold_helmet.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/gold_helmet.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\gold_helmet.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrdnt_selected_etchings/etching_thmbnls/thmbnl_three_trees.jpg
# [INFO] Kandidaat faalt (status=404, size=5067): https://www.rembrandtpainting.net/rmbrdnt_selected_etchings/etchings/three_trees.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\three_trees.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/complete_catalogue/portraits/images/girlwithabroom_thmbnl.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/complete_catalogue/portraits/images/girlwithabroom.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\girlwithabroom.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/thmbnls/thmbnl_lion.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/lion.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\lion.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrdnt_selected_etchings/etching_thmbnls/thmbnl_faust.jpg
# [INFO] Kandidaat faalt (status=404, size=5055): https://www.rembrandtpainting.net/rmbrdnt_selected_etchings/etchings/faust.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\faust.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/thmbnl_homer.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1636-1654/1636-54_images/homer.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\homer.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/thmbnls/smlrsaskia.jpg
# [INFO] Kandidaat faalt (status=404, size=5077): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/smlrsaskia.jpg
# [INFO] Kandidaat faalt (status=404, size=5081): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/s/smlrsaskia.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\smlrsaskia.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1655-1669/1655-69_images/thmbnl_man_in_helmet.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1655-1669/1655-69_images/man_in_helmet.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\man_in_helmet.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/thmbnls/thmbnl_saskia_sleeping.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/saskia_sleeping.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\saskia_sleeping.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1655-1669/1655-69_images/thmbnl_jacob.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1655-1669/1655-69_images/jacob.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\jacob.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/complete_catalogue/landscape/images/thmbnl_ox.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/complete_catalogue/landscape/images/ox.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\ox.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/complete_catalogue/family_portraits/images/thmbnl_titus_1657_58.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/complete_catalogue/family_portraits/images/titus_1657_58.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\titus_1657_58.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1655-1669/1655-69_images/thmbnl_mose.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1655-1669/1655-69_images/mose.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\mose.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1655-1669/1655-69_images/thmbnl_mathew_.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1655-1669/1655-69_images/mathew_.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\mathew_.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrdnt_selected_etchings/etching_thmbnls/thmbnl_woman_nude.jpg
# [INFO] Kandidaat faalt (status=404, size=5065): https://www.rembrandtpainting.net/rmbrdnt_selected_etchings/etchings/woman_nude.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\woman_nude.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/complete_catalogue/storia/images/thmbnl_supper_emmaus.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/complete_catalogue/storia/images/supper_emmaus.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\supper_emmaus.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1655-1669/1655-69_images/thmbnl_syndics.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1655-1669/1655-69_images/syndics.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\syndics.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/thmbnls/smlrmbrndbthshba.jpg
# [INFO] Kandidaat faalt (status=404, size=5089): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/smlrmbrndbthshba.jpg
# [INFO] Kandidaat faalt (status=404, size=5093): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/s/smlrmbrndbthshba.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\smlrmbrndbthshba.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/thmbnls/smlrmbrndtjewish.jpg
# [INFO] Kandidaat faalt (status=404, size=5089): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/smlrmbrndtjewish.jpg
# [INFO] Kandidaat faalt (status=404, size=5093): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/s/smlrmbrndtjewish.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\smlrmbrndtjewish.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/thmbnls/smlrmbrndtboy.jpg
# [INFO] Kandidaat faalt (status=404, size=5083): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/smlrmbrndtboy.jpg
# [INFO] Kandidaat faalt (status=404, size=5087): https://www.rembrandtpainting.net/rmbrndt_selected_drawings/drawing_images/s/smlrmbrndtboy.jpg
# [WAARSCHUWING] Geen bruikbare full-size, thumbnail als fallback.
# [SAVE] Thumbnail opgeslagen als: rembrandt_images\smlrmbrndtboy.jpg
#
# [IMG] Thumbnail: https://www.rembrandtpainting.net/rmbrndt_1655-1669/1655-69_images/thmbnl_prodigal_son.jpg
# [OK] Full gevonden: https://www.rembrandtpainting.net/rmbrndt_1655-1669/1655-69_images/prodigal_son.jpg
# [SAVE] Full-size opgeslagen als: rembrandt_images\prodigal_son.jpg
#
# ----------- PAGINA SAMENVATTING -----------
# Pagina                       : https://www.rembrandtpainting.net/famous_works.html
# Gezién thumbnails (thmbnl)   : 46
# Overgeslagen layout/ads      : 5
# Full-size opgeslagen         : 25
# Thumbnail-fallbacks          : 21
# TOTAAL opgeslagen (deze pag) : 46
# -------------------------------------------
#
#
# =======================================
# [PAGE] Start scrape: https://www.rembrandtpainting.net/rembrandt_books.htm
# =======================================
#
# [INFO] Gevonden <img>-tags op deze pagina: 73
# [SKIP] Layout/advert image: graphics/ad_signature.jpg
# [SKIP] Layout/advert image: graphics/artcomposter_c.jpg
# [SKIP] Layout/advert image: graphics/ad_signature.jpg
# [SKIP] Layout/advert image: graphics/dvdrembrandtsmall.jpg
#
# ----------- PAGINA SAMENVATTING -----------
# Pagina                       : https://www.rembrandtpainting.net/rembrandt_books.htm
# Gezién thumbnails (thmbnl)   : 0
# Overgeslagen layout/ads      : 4
# Full-size opgeslagen         : 0
# Thumbnail-fallbacks          : 0
# TOTAAL opgeslagen (deze pag) : 0
# -------------------------------------------
#
#
# =======================================
#            GLOBALE SAMENVATTING
# =======================================
# Totaal pagina's gescrapet        : 9
# Totaal gezién thumbnails         : 298
# Totaal overgeslagen layout/ads   : 48
# Totaal full-size opgeslagen      : 163
# Totaal thumbnail-fallbacks       : 135
# ---------------------------------------
# TOTAAL afbeeldingen opgeslagen   : 298
# Uitvoer-map                      : rembrandt_images
# =======================================
